# %%
import pandas as pd
from uploading_data import *
from data_exploration import *

# %%
start_date = pd.to_datetime("2012-09-22")
end_date = pd.to_datetime("2012-12-31")

load_all(start_date, end_date, True)
# Out:
# Processing date: 2012-09-24, Tickers: ['CORN', 'CPER', 'DBC', 'EDEN', 'EFNL', 'EIS', 'EUSA', 'EWA', 'EWC', 'EWD', 'EWG', 'EWH', 'EWI', 'EWJ', 'EWK', 'EWL', 'EWN', 'EWO', 'EWP', 'EWQ', 'EWS', 'EWT', 'EWU', 'EWW', 'EWY', 'EWZ', 'GAZ', 'GLD', 'GSG', 'IAU', 'INDA', 'JJC', 'JJU', 'JO', 'MCHI', 'OIL', 'PALL', 'PPLT', 'SGG', 'SGOL', 'SIVR', 'SLV', 'SOYB', 'UNG', 'USCI', 'USO', 'WEAT', 'XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLU', 'XLV', 'XLY']
# Processing date: 2012-09-25, Tickers: ['CORN', 'CPER', 'DBC', 'EDEN', 'EFNL', 'EIS', 'EUSA', 'EWA', 'EWC', 'EWD', 'EWG', 'EWH', 'EWI', 'EWJ', 'EWK', 'EWL', 'EWN', 'EWO', 'EWP', 'EWQ', 'EWS', 'EWT', 'EWU', 'EWW', 'EWY', 'EWZ', 'GAZ', 'GLD', 'GSG', 'IAU', 'INDA', 'JJC', 'JJU', 'JO', 'MCHI', 'OIL', 'PALL', 'PPLT', 'SGG', 'SGOL', 'SIVR', 'SLV', 'SOYB', 'UNG', 'USCI', 'USO', 'WEAT', 'XLB', 'XLE', 'XLF', 'XLI', 'XLK', 'XLP', 'XLU', 'XLV', 'XLY']
# ...

# %%
input_folder = "data/dates"
output_folder = "data/period_data.tar"
compress_to_tar(input_folder, output_folder)
# Out:
# Compressing folder 'data/dates' into 'data/period_data.tar'...
# Folder successfully compressed into 'data/period_data.tar'.
